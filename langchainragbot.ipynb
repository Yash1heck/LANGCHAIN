# %%
# Out:
#   Cell In[3], line 1
#     python.exe -m pip install websockets --force-reinstall
#                   ^
# SyntaxError: invalid syntax

# %%
! pip install -q --user --upgrade langchain langchain-openai langchain-core langchain_community docx2txt pypdf  langchain_chroma sentence_transformers
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.8

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = ""
os.environ["LANGCHAIN_PROJECT"] = "langchain-course"

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
! pip install docx2txt pypdf unstructured
# Out:
# Requirement already satisfied: docx2txt in c:\python312\lib\site-packages (0.9)
# Requirement already satisfied: pypdf in c:\users\yaswa\appdata\roaming\python\python312\site-packages (6.6.2)
# Collecting unstructured
#   Downloading unstructured-0.18.31-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset-normalizer in c:\python312\lib\site-packages (from unstructured) (3.3.2)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Downloading lxml-6.0.2-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting nltk (from unstructured)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from unstructured) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\python312\lib\site-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2026.1.31-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ----------------------- ------------- 614.4/981.5 kB 19.5 MB/s eta 0:00:01
#      ------------------------------------- 981.5/981.5 kB 15.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from unstructured) (2.4.2)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: backoff in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\python312\lib\site-packages (from unstructured) (4.15.0)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.42.10-py3-none-any.whl.metadata (23 kB)
# Collecting wrapt (from unstructured)
#   Downloading wrapt-2.1.1-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: tqdm in c:\python312\lib\site-packages (from unstructured) (4.67.3)
# Requirement already satisfied: psutil in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from unstructured) (6.1.1)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting numba (from unstructured)
#   Downloading numba-0.63.1-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\python312\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from dataclasses-json->unstructured) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\python312\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in c:\python312\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from nltk->unstructured) (8.3.1)
# Requirement already satisfied: joblib in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from nltk->unstructured) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from nltk->unstructured) (2026.1.15)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba->unstructured)
#   Downloading llvmlite-0.46.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting numpy (from unstructured)
#   Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 3.4 MB/s eta 0:00:00
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests->unstructured) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests->unstructured) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from tqdm->unstructured) (0.4.6)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured)
#   Downloading cryptography-46.0.4-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting httpcore>=1.0.9 (from unstructured-client->unstructured)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from unstructured-client->unstructured) (2.12.5)
# Collecting pypdfium2>=5.0.0 (from unstructured-client->unstructured)
#   Downloading pypdfium2-5.3.0-py3-none-win_amd64.whl.metadata (67 kB)
#      ---------------------------------------- 0.0/67.8 kB ? eta -:--:--
#      ---------------------------------------- 67.8/67.8 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from unstructured-client->unstructured) (1.0.0)
# Collecting cffi>=2.0.0 (from cryptography>=3.1->unstructured-client->unstructured)
#   Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting h11>=0.16 (from httpcore>=1.0.9->unstructured-client->unstructured)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: anyio in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.8.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: pycparser in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Downloading unstructured-0.18.31-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------  1.8/1.8 MB 57.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 38.0 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    --------------------------------------- 608.4/608.4 kB 37.4 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 112.2/112.2 kB 6.4 MB/s eta 0:00:00
# Downloading lxml-6.0.2-cp312-cp312-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------ --------------------------- 1.3/4.0 MB 40.6 MB/s eta 0:00:01
#    ------------- -------------------------- 1.4/4.0 MB 22.0 MB/s eta 0:00:01
#    ------------- -------------------------- 1.4/4.0 MB 22.0 MB/s eta 0:00:01
#    ------------- -------------------------- 1.4/4.0 MB 22.0 MB/s eta 0:00:01
#    ------------- -------------------------- 1.4/4.0 MB 22.0 MB/s eta 0:00:01
#    ------------- -------------------------- 1.4/4.0 MB 22.0 MB/s eta 0:00:01
#    ------------------ --------------------- 1.9/4.0 MB 5.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.7/4.0 MB 7.5 MB/s eta 0:00:01
#    ------------------------------ --------- 3.0/4.0 MB 7.7 MB/s eta 0:00:01
#    ------------------------------ --------- 3.0/4.0 MB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  4.0/4.0 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 6.1 MB/s eta 0:00:00
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.5 MB 6.1 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.5 MB 4.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.5 MB 4.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.5 MB 3.7 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.9/1.5 MB 3.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.5 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.5 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 1.5/1.5 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993367 sha256=6e2d870e598eaf57e58be949a9f56d92291792cbb8f3ba2fff99594491df8392
#   Stored in directory: c:\users\yaswa\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: filetype, wrapt, rapidfuzz, python-magic, python-iso639, pypdfium2, olefile, numpy, lxml, llvmlite, langdetect, html5lib, h11, emoji, cffi, aiofiles, python-oxmsg, numba, nltk, httpcore, cryptography, unstructured-client, unstructured
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python312\\Scripts\\filetype.exe' -> 'C:\\Python312\\Scripts\\filetype.exe.deleteme'
#
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from typing import List
from langchain_core.documents import Document

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len
)

docx_loader = Docx2txtLoader("docs/GreenGrow Innovations_ Company History.docx")
documents = docx_loader.load()

print(len(documents))

splits = text_splitter.split_documents(documents)

print(f"Split the documents into {len(splits)} chunks.")
# Out:
# 1
# Split the documents into 2 chunks.

# %%
documents[0]
# Out:
# Document(metadata={'source': 'docs/GreenGrow Innovations_ Company History.docx'}, page_content="GreenGrow Innovations was founded in 2010 by Sarah Chen and Michael Rodriguez, two agricultural engineers with a passion for sustainable farming. The company started in a small garage in Portland, Oregon, with a simple mission: to make farming more environmentally friendly and efficient.\n\n\n\nIn its early days, GreenGrow focused on developing smart irrigation systems that could significantly reduce water usage in agriculture. Their first product, the WaterWise Sensor, was launched in 2012 and quickly gained popularity among local farmers. This success allowed the company to expand its research and development efforts.\n\n\n\nBy 2015, GreenGrow had outgrown its garage origins and moved into a proper office and research facility in the outskirts of Portland. This move coincided with the development of their second major product, the SoilHealth Monitor, which used advanced sensors to analyze soil composition and provide real-time recommendations for optimal crop growth.\n\n\n\nThe company's breakthrough came in 2018 with the introduction of the EcoHarvest System, an integrated solution that combined smart irrigation, soil monitoring, and automated harvesting techniques. This system caught the attention of large-scale farmers across the United States, propelling GreenGrow to national prominence.\n\n\n\nToday, GreenGrow Innovations employs over 200 people and has expanded its operations to include offices in California and Iowa. The company continues to focus on developing sustainable agricultural technologies, with ongoing projects in vertical farming, drought-resistant crop development, and AI-powered farm management systems.\n\n\n\nDespite its growth, GreenGrow remains committed to its original mission of promoting sustainable farming practices. The company regularly partners with universities and research institutions to advance the field of agricultural technology and hosts annual conferences to share knowledge with farmers and other industry professionals.")

# %%
splits[1]
# Out:
# Document(metadata={'source': 'docs/GreenGrow Innovations_ Company History.docx'}, page_content="The company's breakthrough came in 2018 with the introduction of the EcoHarvest System, an integrated solution that combined smart irrigation, soil monitoring, and automated harvesting techniques. This system caught the attention of large-scale farmers across the United States, propelling GreenGrow to national prominence.\n\n\n\nToday, GreenGrow Innovations employs over 200 people and has expanded its operations to include offices in California and Iowa. The company continues to focus on developing sustainable agricultural technologies, with ongoing projects in vertical farming, drought-resistant crop development, and AI-powered farm management systems.\n\n\n\nDespite its growth, GreenGrow remains committed to its original mission of promoting sustainable farming practices. The company regularly partners with universities and research institutions to advance the field of agricultural technology and hosts annual conferences to share knowledge with farmers and other industry professionals.")

# %%
splits[0].metadata
# Out:
# {'source': 'docs/GreenGrow Innovations_ Company History.docx'}

# %%
splits[0].page_content
# Out:
# 'GreenGrow Innovations was founded in 2010 by Sarah Chen and Michael Rodriguez, two agricultural engineers with a passion for sustainable farming. The company started in a small garage in Portland, Oregon, with a simple mission: to make farming more environmentally friendly and efficient.\n\n\n\nIn its early days, GreenGrow focused on developing smart irrigation systems that could significantly reduce water usage in agriculture. Their first product, the WaterWise Sensor, was launched in 2012 and quickly gained popularity among local farmers. This success allowed the company to expand its research and development efforts.\n\n\n\nBy 2015, GreenGrow had outgrown its garage origins and moved into a proper office and research facility in the outskirts of Portland. This move coincided with the development of their second major product, the SoilHealth Monitor, which used advanced sensors to analyze soil composition and provide real-time recommendations for optimal crop growth.'

# %%
def load_documents(folder_path: str) -> List[Document]:
    documents = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if filename.endswith('.pdf'):
            loader = PyPDFLoader(file_path)
        elif filename.endswith('.docx'):
            loader = Docx2txtLoader(file_path)
        else:
            print(f"Unsupported file type: {filename}")
            continue
        documents.extend(loader.load())
    return documents

# Load documents from a folder
folder_path = "docs"
documents = load_documents(folder_path)

print(f"Loaded {len(documents)} documents from the folder.")
splits = text_splitter.split_documents(documents)
print(f"Split the documents into {len(splits)} chunks.")
# Out:
# Loaded 5 documents from the folder.
# Split the documents into 8 chunks.

# %%
# !pip install sentence_transformers
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
document_embeddings = embedding_function.embed_documents([split.page_content for split in splits])
document_embeddings[0]
# Out:
# C:\Users\yaswa\AppData\Local\Temp\ipykernel_29968\3719339062.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\yaswa\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:130: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\yaswa\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [0.0293357465416193,
#  -0.027797531336545944,
#  -0.01846340484917164,
#  -0.058924250304698944,
#  0.08951887488365173,
#  -0.026082225143909454,
#  -0.10806205123662949,
#  0.03759301081299782,
#  -0.005008654668927193,
#  -0.041687216609716415,
#  -0.016387708485126495,
#  -0.02612929232418537,
#  -0.0313599668443203,
#  0.010636315681040287,
#  -0.07282692939043045,
#  -0.0030148024670779705,
#  -0.01876574382185936,
#  -0.01873071677982807,
#  0.0665455013513565,
#  -0.07033520936965942,
#  0.003246106207370758,
#  -0.01593754068017006,
#  0.06552284955978394,
#  0.014457416720688343,
# %%
# import shutil

# shutil.rmtree('chroma_db')

# %% [markdown]
# ###Create and persist Chroma vector store

# %%
from langchain_chroma import Chroma

embedding_function = OpenAIEmbeddings()
collection_name = "my_collection"
vectorstore = Chroma.from_documents(collection_name=collection_name, documents=splits, embedding=embedding_function, persist_directory="./chroma_db")
#db.persist()

print("Vector store created and persisted to './chroma_db'")
# Out:
# Vector store created and persisted to './chroma_db'

# %%
# 5. Perform similarity search

query = "When was GreenGrow Innovations founded?"
search_results = vectorstore.similarity_search(query, k=2)

print(f"\nTop 2 most relevant chunks for the query: '{query}'\n")
for i, result in enumerate(search_results, 1):
    print(f"Result {i}:")
    print(f"Source: {result.metadata.get('source', 'Unknown')}")
    print(f"Content: {result.page_content}")
    print()
# Out:
# Top 2 most relevant chunks for the query: 'When was GreenGrow Innovations founded?'
#
# Result 1:
# Source: docs\GreenGrow Innovations_ Company History.docx
# Content: The company's breakthrough came in 2018 with the introduction of the EcoHarvest System, an integrated solution that combined smart irrigation, soil monitoring, and automated harvesting techniques. This system caught the attention of large-scale farmers across the United States, propelling GreenGrow to national prominence.
#
#
#
# Today, GreenGrow Innovations employs over 200 people and has expanded its operations to include offices in California and Iowa. The company continues to focus on developing sustainable agricultural technologies, with ongoing projects in vertical farming, drought-resistant crop development, and AI-powered farm management systems.
#
#
#
# Despite its growth, GreenGrow remains committed to its original mission of promoting sustainable farming practices. The company regularly partners with universities and research institutions to advance the field of agricultural technology and hosts annual conferences to share knowledge with farmers and other industry professionals.
#
# Result 2:
# Source: docs\GreenGrow Innovations_ Company History.docx
# Content: GreenGrow Innovations was founded in 2010 by Sarah Chen and Michael Rodriguez, two agricultural engineers with a passion for sustainable farming. The company started in a small garage in Portland, Oregon, with a simple mission: to make farming more environmentally friendly and efficient.
#
#
#
# In its early days, GreenGrow focused on developing smart irrigation systems that could significantly reduce water usage in agriculture. Their first product, the WaterWise Sensor, was launched in 2012 and quickly gained popularity among local farmers. This success allowed the company to expand its research and development efforts.
#
#
#
# By 2015, GreenGrow had outgrown its garage origins and moved into a proper office and research facility in the outskirts of Portland. This move coincided with the development of their second major product, the SoilHealth Monitor, which used advanced sensors to analyze soil composition and provide real-time recommendations for optimal crop growth.

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 2})
retriever.invoke("When was GreenGrow Innovations founded?")
# Out:
# [Document(id='b3bf984d-159c-4901-b8e2-a419c6645a41', metadata={'source': 'docs\\GreenGrow Innovations_ Company History.docx'}, page_content="The company's breakthrough came in 2018 with the introduction of the EcoHarvest System, an integrated solution that combined smart irrigation, soil monitoring, and automated harvesting techniques. This system caught the attention of large-scale farmers across the United States, propelling GreenGrow to national prominence.\n\n\n\nToday, GreenGrow Innovations employs over 200 people and has expanded its operations to include offices in California and Iowa. The company continues to focus on developing sustainable agricultural technologies, with ongoing projects in vertical farming, drought-resistant crop development, and AI-powered farm management systems.\n\n\n\nDespite its growth, GreenGrow remains committed to its original mission of promoting sustainable farming practices. The company regularly partners with universities and research institutions to advance the field of agricultural technology and hosts annual conferences to share knowledge with farmers and other industry professionals."),
#  Document(id='e7f47e1a-b0b2-4c58-be2c-58cebbcac988', metadata={'source': 'docs\\GreenGrow Innovations_ Company History.docx'}, page_content='GreenGrow Innovations was founded in 2010 by Sarah Chen and Michael Rodriguez, two agricultural engineers with a passion for sustainable farming. The company started in a small garage in Portland, Oregon, with a simple mission: to make farming more environmentally friendly and efficient.\n\n\n\nIn its early days, GreenGrow focused on developing smart irrigation systems that could significantly reduce water usage in agriculture. Their first product, the WaterWise Sensor, was launched in 2012 and quickly gained popularity among local farmers. This success allowed the company to expand its research and development efforts.\n\n\n\nBy 2015, GreenGrow had outgrown its garage origins and moved into a proper office and research facility in the outskirts of Portland. This move coincided with the development of their second major product, the SoilHealth Monitor, which used advanced sensors to analyze soil composition and provide real-time recommendations for optimal crop growth.')]

# %%
from langchain_core.prompts import ChatPromptTemplate
template = """Answer the question based only on the following context:
{context}

Question: {question}

Answer: """
prompt = ChatPromptTemplate.from_template(template)

# %%
from langchain_core.runnables  import RunnablePassthrough
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()} | prompt
)
rag_chain.invoke("When was GreenGrow Innovations founded?")
# Out:
# ChatPromptValue(messages=[HumanMessage(content='Answer the question based only on the following context:\n[Document(id=\'b3bf984d-159c-4901-b8e2-a419c6645a41\', metadata={\'source\': \'docs\\\\GreenGrow Innovations_ Company History.docx\'}, page_content="The company\'s breakthrough came in 2018 with the introduction of the EcoHarvest System, an integrated solution that combined smart irrigation, soil monitoring, and automated harvesting techniques. This system caught the attention of large-scale farmers across the United States, propelling GreenGrow to national prominence.\\n\\n\\n\\nToday, GreenGrow Innovations employs over 200 people and has expanded its operations to include offices in California and Iowa. The company continues to focus on developing sustainable agricultural technologies, with ongoing projects in vertical farming, drought-resistant crop development, and AI-powered farm management systems.\\n\\n\\n\\nDespite its growth, GreenGrow remains committed to its original mission of promoting sustainable farming practices. The company regularly partners with universities and research institutions to advance the field of agricultural technology and hosts annual conferences to share knowledge with farmers and other industry professionals."), Document(id=\'e7f47e1a-b0b2-4c58-be2c-58cebbcac988\', metadata={\'source\': \'docs\\\\GreenGrow Innovations_ Company History.docx\'}, page_content=\'GreenGrow Innovations was founded in 2010 by Sarah Chen and Michael Rodriguez, two agricultural engineers with a passion for sustainable farming. The company started in a small garage in Portland, Oregon, with a simple mission: to make farming more environmentally friendly and efficient.\\n\\n\\n\\nIn its early days, GreenGrow focused on developing smart irrigation systems that could significantly reduce water usage in agriculture. Their first product, the WaterWise Sensor, was launched in 2012 and quickly gained popularity among local farmers. This success allowed the company to expand its research and development efforts.\\n\\n\\n\\nBy 2015, GreenGrow had outgrown its garage origins and moved into a proper office and research facility in the outskirts of Portland. This move coincided with the development of their second major product, the SoilHealth Monitor, which used advanced sensors to analyze soil composition and provide real-time recommendations for optimal crop growth.\')]\n\nQuestion: When was GreenGrow Innovations founded?\n\nAnswer: ', additional_kwargs={}, response_metadata={})])

# %%
def docs2str(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
rag_chain = (
    {"context": retriever | docs2str, "question": RunnablePassthrough()} | prompt
)
rag_chain.invoke("When was GreenGrow Innovations founded?")
# Out:
# ChatPromptValue(messages=[HumanMessage(content="Answer the question based only on the following context:\nThe company's breakthrough came in 2018 with the introduction of the EcoHarvest System, an integrated solution that combined smart irrigation, soil monitoring, and automated harvesting techniques. This system caught the attention of large-scale farmers across the United States, propelling GreenGrow to national prominence.\n\n\n\nToday, GreenGrow Innovations employs over 200 people and has expanded its operations to include offices in California and Iowa. The company continues to focus on developing sustainable agricultural technologies, with ongoing projects in vertical farming, drought-resistant crop development, and AI-powered farm management systems.\n\n\n\nDespite its growth, GreenGrow remains committed to its original mission of promoting sustainable farming practices. The company regularly partners with universities and research institutions to advance the field of agricultural technology and hosts annual conferences to share knowledge with farmers and other industry professionals.\n\nGreenGrow Innovations was founded in 2010 by Sarah Chen and Michael Rodriguez, two agricultural engineers with a passion for sustainable farming. The company started in a small garage in Portland, Oregon, with a simple mission: to make farming more environmentally friendly and efficient.\n\n\n\nIn its early days, GreenGrow focused on developing smart irrigation systems that could significantly reduce water usage in agriculture. Their first product, the WaterWise Sensor, was launched in 2012 and quickly gained popularity among local farmers. This success allowed the company to expand its research and development efforts.\n\n\n\nBy 2015, GreenGrow had outgrown its garage origins and moved into a proper office and research facility in the outskirts of Portland. This move coincided with the development of their second major product, the SoilHealth Monitor, which used advanced sensors to analyze soil composition and provide real-time recommendations for optimal crop growth.\n\nQuestion: When was GreenGrow Innovations founded?\n\nAnswer: ", additional_kwargs={}, response_metadata={})])

# %%
rag_chain = (
    {"context": retriever | docs2str, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)
question = "When was GreenGrow Innovations founded?"
response = rag_chain.invoke(question)
print(response)
# Out:
# GreenGrow Innovations was founded in 2010.

# %% [markdown]
# ###Conversational RAG
#
# ####Handling Follow Up Questions

# %%
# Example conversation
from langchain_core.messages import HumanMessage, AIMessage
chat_history = []
chat_history.extend([
    HumanMessage(content=question),
    AIMessage(content=response)
])

# %%
chat_history
# Out:
# [HumanMessage(content='When was GreenGrow Innovations founded?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='GreenGrow Innovations was founded in 2010.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]

# %%
from langchain_core.prompts import MessagesPlaceholder
contextualize_q_system_prompt = (
    "Given a chat history and the latest user question "
    "which might reference context in the chat history, "
    "formulate a standalone question which can be understood "
    "without the chat history. Do NOT answer the question, "
    "just reformulate it if needed and otherwise return it as is."
)

contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", contextualize_q_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)

# history_aware_retriever = create_history_aware_retriever(
#     llm, retriever, contextualize_q_prompt
# )
contextualize_chain = contextualize_q_prompt | llm | StrOutputParser()
contextualize_chain.invoke({"input": "Where it is headquartered?", "chat_history": chat_history})
# Out:
# 'Where is GreenGrow Innovations headquartered?'

# %%
 ! pip install -U langchain langchain-community
# Out:
# Requirement already satisfied: langchain in c:\users\yaswa\appdata\roaming\python\python312\site-packages (1.2.8)
# Requirement already satisfied: langchain-community in c:\users\yaswa\appdata\roaming\python\python312\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain) (1.2.9)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.7 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (2.0.46)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (9.1.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (0.6.9)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (24.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in c:\python312\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python312\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2024.6.2)
# Requirement already satisfied: greenlet>=1 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.1)
# Requirement already satisfied: anyio in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain) (1.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain-classic
# Out:
# Requirement already satisfied: langchain-classic in c:\users\yaswa\appdata\roaming\python\python312\site-packages (1.0.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-classic) (1.2.9)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-classic) (1.1.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-classic) (0.6.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-classic) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-classic) (6.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-classic) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-classic) (2.0.46)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (9.1.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\python312\lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (0.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\python312\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python312\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2024.6.2)
# Requirement already satisfied: greenlet>=1 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.3.1)
# Requirement already satisfied: anyio in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain-classic) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yaswa\appdata\roaming\python\python312\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_classic.chains import create_history_aware_retriever
history_aware_retriever = create_history_aware_retriever(
    llm, retriever, contextualize_q_prompt
)
history_aware_retriever.invoke({"input": "Where it is headquartered?", "chat_history": chat_history})
# Out:
# [Document(id='b3bf984d-159c-4901-b8e2-a419c6645a41', metadata={'source': 'docs\\GreenGrow Innovations_ Company History.docx'}, page_content="The company's breakthrough came in 2018 with the introduction of the EcoHarvest System, an integrated solution that combined smart irrigation, soil monitoring, and automated harvesting techniques. This system caught the attention of large-scale farmers across the United States, propelling GreenGrow to national prominence.\n\n\n\nToday, GreenGrow Innovations employs over 200 people and has expanded its operations to include offices in California and Iowa. The company continues to focus on developing sustainable agricultural technologies, with ongoing projects in vertical farming, drought-resistant crop development, and AI-powered farm management systems.\n\n\n\nDespite its growth, GreenGrow remains committed to its original mission of promoting sustainable farming practices. The company regularly partners with universities and research institutions to advance the field of agricultural technology and hosts annual conferences to share knowledge with farmers and other industry professionals."),
#  Document(id='e7f47e1a-b0b2-4c58-be2c-58cebbcac988', metadata={'source': 'docs\\GreenGrow Innovations_ Company History.docx'}, page_content='GreenGrow Innovations was founded in 2010 by Sarah Chen and Michael Rodriguez, two agricultural engineers with a passion for sustainable farming. The company started in a small garage in Portland, Oregon, with a simple mission: to make farming more environmentally friendly and efficient.\n\n\n\nIn its early days, GreenGrow focused on developing smart irrigation systems that could significantly reduce water usage in agriculture. Their first product, the WaterWise Sensor, was launched in 2012 and quickly gained popularity among local farmers. This success allowed the company to expand its research and development efforts.\n\n\n\nBy 2015, GreenGrow had outgrown its garage origins and moved into a proper office and research facility in the outskirts of Portland. This move coincided with the development of their second major product, the SoilHealth Monitor, which used advanced sensors to analyze soil composition and provide real-time recommendations for optimal crop growth.')]

# %%
retriever.invoke("Where it is headquartered?")
# Out:
# [Document(id='8bde6c28-5f80-4018-bb84-3097055cd214', metadata={'source': 'docs\\Company_ QuantumNext Systems.docx'}, page_content='Company: QuantumNext Systems\n\nHeadquarters: QuantumNext Systems is headquartered in Bangalore, Karnataka, India. The company, specializing in quantum computing and advanced data processing, is situated in the bustling tech metropolis of Bangalore, often referred to as the "Silicon Valley of India." From this technology capital, QuantumNext Systems is well-positioned to tap into India\'s rich pool of engineering talent and growing tech ecosystem, enabling it to push the boundaries of computational innovation.'),
#  Document(id='8b3c17ec-52d4-46f2-bb5f-0ed6b9a54dd9', metadata={'source': 'docs\\Company_ TechWave Innovations.docx'}, page_content='Company: TechWave Innovations\n\nHeadquarters: TechWave Innovations is headquartered in San Francisco, California, USA. As a leader in cutting-edge AI and machine learning solutions, the company thrives in the heart of Silicon Valley, benefiting from its proximity to tech giants and a dynamic startup ecosystem. With its headquarters in this global technology hub, TechWave Innovations has access to top talent and a vast network of innovation-driven enterprises.')]

# %%
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain

qa_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI assistant. Use the following context to answer the user's question."),
    #  ("system", "Tell me joke on Programming"),
    ("system", "Context: {context}"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{input}")
])

question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)

rag_chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

# %%
rag_chain.invoke({"input": "Where it is headquartered?", "chat_history":chat_history})
# Out:
# {'input': 'Where it is headquartered?',
#  'chat_history': [HumanMessage(content='When was GreenGrow Innovations founded?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='GreenGrow Innovations was founded in 2010.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'context': [Document(id='b3bf984d-159c-4901-b8e2-a419c6645a41', metadata={'source': 'docs\\GreenGrow Innovations_ Company History.docx'}, page_content="The company's breakthrough came in 2018 with the introduction of the EcoHarvest System, an integrated solution that combined smart irrigation, soil monitoring, and automated harvesting techniques. This system caught the attention of large-scale farmers across the United States, propelling GreenGrow to national prominence.\n\n\n\nToday, GreenGrow Innovations employs over 200 people and has expanded its operations to include offices in California and Iowa. The company continues to focus on developing sustainable agricultural technologies, with ongoing projects in vertical farming, drought-resistant crop development, and AI-powered farm management systems.\n\n\n\nDespite its growth, GreenGrow remains committed to its original mission of promoting sustainable farming practices. The company regularly partners with universities and research institutions to advance the field of agricultural technology and hosts annual conferences to share knowledge with farmers and other industry professionals."),
#   Document(id='e7f47e1a-b0b2-4c58-be2c-58cebbcac988', metadata={'source': 'docs\\GreenGrow Innovations_ Company History.docx'}, page_content='GreenGrow Innovations was founded in 2010 by Sarah Chen and Michael Rodriguez, two agricultural engineers with a passion for sustainable farming. The company started in a small garage in Portland, Oregon, with a simple mission: to make farming more environmentally friendly and efficient.\n\n\n\nIn its early days, GreenGrow focused on developing smart irrigation systems that could significantly reduce water usage in agriculture. Their first product, the WaterWise Sensor, was launched in 2012 and quickly gained popularity among local farmers. This success allowed the company to expand its research and development efforts.\n\n\n\nBy 2015, GreenGrow had outgrown its garage origins and moved into a proper office and research facility in the outskirts of Portland. This move coincided with the development of their second major product, the SoilHealth Monitor, which used advanced sensors to analyze soil composition and provide real-time recommendations for optimal crop growth.')],
#  'answer': 'GreenGrow Innovations is headquartered in Portland, Oregon.'}

# %% [markdown]
# ###Building Multi User Chatbot

# %%
import sqlite3
from datetime import datetime

DB_NAME = "rag_app.db"

def get_db_connection():
    conn = sqlite3.connect(DB_NAME)
    conn.row_factory = sqlite3.Row
    return conn

def create_application_logs():
    conn = get_db_connection()
    conn.execute('''CREATE TABLE IF NOT EXISTS application_logs
                    (id INTEGER PRIMARY KEY AUTOINCREMENT,
                     session_id TEXT,
                     user_query TEXT,
                     gpt_response TEXT,
                     model TEXT,
                     created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP)''')
    conn.close()

def insert_application_logs(session_id, user_query, gpt_response, model):
    conn = get_db_connection()
    conn.execute('INSERT INTO application_logs (session_id, user_query, gpt_response, model) VALUES (?, ?, ?, ?)',
                 (session_id, user_query, gpt_response, model))
    conn.commit()
    conn.close()

def get_chat_history(session_id):
    conn = get_db_connection()
    cursor = conn.cursor()
    cursor.execute('SELECT user_query, gpt_response FROM application_logs WHERE session_id = ? ORDER BY created_at', (session_id,))
    messages = []
    for row in cursor.fetchall():
        messages.extend([
            {"role": "human", "content": row['user_query']},
            {"role": "ai", "content": row['gpt_response']}
        ])
    conn.close()
    return messages

# Initialize the database
create_application_logs()

# %%
import uuid
session_id = str(uuid.uuid4())
chat_history = get_chat_history(session_id)
print(chat_history)
question1 = "When was GreenGrow Innovations founded?"
answer1 = rag_chain.invoke({"input": question1, "chat_history":chat_history})['answer']
insert_application_logs(session_id, question1, answer1, "gpt-4-o-mini")
print(f"Human: {question1}")
print(f"AI: {answer1}\n")
# Out:
# []
# Human: When was GreenGrow Innovations founded?
# AI: GreenGrow Innovations was founded in 2010.

# %%
question2 = "Where it is headquartered?"
chat_history = get_chat_history(session_id)
print(chat_history)
answer2 = rag_chain.invoke({"input": question2, "chat_history":chat_history})['answer']
insert_application_logs(session_id, question2, answer2, "gpt-3.5-turbo")
print(f"Human: {question2}")
print(f"AI: {answer2}\n")
# Out:
# [{'role': 'human', 'content': 'When was GreenGrow Innovations founded?'}, {'role': 'ai', 'content': 'GreenGrow Innovations was founded in 2010.'}]
# Human: Where it is headquartered?
# AI: GreenGrow Innovations is headquartered in Portland, Oregon.

# %% [markdown]
# New User

# %%
session_id = str(uuid.uuid4())
question = "What is GreenGrow"
chat_history = get_chat_history(session_id)
print(chat_history)
answer = rag_chain.invoke({"input": question, "chat_history":chat_history})['answer']
insert_application_logs(session_id, question, answer, "gpt-3.5-turbo")
print(f"Human: {question}")
print(f"AI: {answer}\n")
# Out:
# []
# Human: What is GreenGrow
# AI: GreenGrow Innovations is a company that specializes in developing sustainable agricultural technologies. Founded in 2010 in Portland, Oregon, by agricultural engineers Sarah Chen and Michael Rodriguez, the company aims to make farming more environmentally friendly and efficient.
#
# GreenGrow initially focused on smart irrigation systems, launching their first product, the WaterWise Sensor, in 2012. As the company grew, it expanded its product offerings, including the SoilHealth Monitor in 2015 and the EcoHarvest System in 2018, which integrated various agricultural technologies.
#
# Today, GreenGrow employs over 200 people and has offices in California and Iowa. The company continues to work on projects related to vertical farming, drought-resistant crops, and AI-powered farm management systems, while maintaining its commitment to promoting sustainable farming practices through partnerships and knowledge-sharing initiatives.
